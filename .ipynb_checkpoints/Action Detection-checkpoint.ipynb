# %% [markdown]
# # 1. Import and Install Dependencies

# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import mediapipe as mp

# %% [markdown]
# # 2. Keypoints using MP Holistic

# %%
mp_holistic = mp.solutions.holistic # Holistic model
mp_drawing = mp.solutions.drawing_utils # Drawing utilities

# %%
def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # COLOR CONVERSION BGR 2 RGB
    image.flags.writeable = False                  # Image is no longer writeable
    results = model.process(image)                 # Make prediction
    image.flags.writeable = True                   # Image is now writeable 
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # COLOR COVERSION RGB 2 BGR
    return image, results

# %%
def draw_landmarks(image, results):
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_CONTOURS) # Draw face connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS) # Draw pose connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw right hand connections

# %%
def draw_styled_landmarks(image, results):
    # Draw face connections
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_CONTOURS, 
                             mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1), 
                             mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                             ) 
    # Draw pose connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                             ) 
    # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                             ) 
    # Draw right hand connections  
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                             )

# %%
cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)

        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()

# %%
results

# %%
draw_landmarks(frame, results)

# %%
plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))

# %% [markdown]
# # 3. Extract Keypoint Values

# %%
pose = []
for res in results.pose_landmarks.landmark:
    test = np.array([res.x, res.y, res.z, res.visibility])
    pose.append(test)

# %%
pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(132)
face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(1404)
lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)

# %%
def extract_keypoints(results):
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(468*3)
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    return np.concatenate([pose, face, lh, rh])

# %%
result_test = extract_keypoints(results)

# %%
result_test

# %%
np.save('0', result_test)

# %%
np.load('0.npy')

# %% [markdown]
# # 4. Setup Folders for Collection

# %%
# Path for exported data, numpy arrays
DATA_PATH = os.path.join('MP_Data') 

# Actions that we try to detect
actions = np.array(['hello', 'thanks', 'iloveyou'])

# Thirty videos worth of data
no_sequences = 30

# Videos are going to be 30 frames in length
sequence_length = 30

# %%
# hello
## 0
## 1
## 2
## ...
## 29
# thanks

# I love you

# %%
for action in actions: 
    for sequence in range(no_sequences):
        try: 
            os.makedirs(os.path.join(DATA_PATH, action, str(sequence)))
        except:
            pass

# %% [markdown]
# # 5. Collect Keypoint Values for Training and Testing

# %%
cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    # NEW LOOP
    # Loop through actions
    for action in actions:
        # Loop through sequences aka videos
        for sequence in range(no_sequences):
            # Loop through video length aka sequence length
            for frame_num in range(sequence_length):

                # Read feed
                ret, frame = cap.read()

                # Make detections
                image, results = mediapipe_detection(frame, holistic)

                # Draw landmarks
                draw_styled_landmarks(image, results)
                
                # NEW Apply wait logic
                if frame_num == 0: 
                    cv2.putText(image, 'STARTING COLLECTION', (120,200), 
                               cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255, 0), 4, cv2.LINE_AA)
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)
                    cv2.waitKey(2000)
                else: 
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)
                
                # NEW Export keypoints
                keypoints = extract_keypoints(results)
                npy_path = os.path.join(DATA_PATH, action, str(sequence), str(frame_num))
                np.save(npy_path, keypoints)

                # Break gracefully
                if cv2.waitKey(10) & 0xFF == ord('q'):
                    break
                    
    cap.release()
    cv2.destroyAllWindows()

# %%
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # 6. Preprocess Data and Create Labels and Features

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# %%
label_map = {label:num for num, label in enumerate(actions)}

# %%
label_map
# Out:
# {'hello': 0, 'thanks': 1, 'iloveyou': 2}

# %%
sequences, labels = [], []
for action in actions:
    for sequence in range(no_sequences):
        window = []
        for frame_num in range(sequence_length):
            res = np.load(os.path.join(DATA_PATH, action, str(sequence), "{}.npy".format(frame_num)))
            window.append(res)
        sequences.append(window)
        labels.append(label_map[action])

# %%
np.array(sequences).shape
# Out:
# (90, 30, 1662)

# %%
np.array(labels).shape
# Out:
# (90,)

# %%
X = np.array(sequences)

# %%
X.shape
# Out:
# (90, 30, 1662)

# %%
y = to_categorical(labels).astype(int)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1)

# %%
y_train.shape
# Out:
# (81, 3)

# %% [markdown]
# # 7. Build and Train LSTM Neural Network

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import TensorBoard

# %%
log_dir = os.path.join('Logs')
tb_callback = TensorBoard(log_dir=log_dir)

# %%
model = Sequential()
model.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(30,1662)))
model.add(LSTM(128, return_sequences=True, activation='relu'))
model.add(LSTM(64, return_sequences=False, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(actions.shape[0], activation='softmax'))

# %%
res = [.7, 0.2, 0.1]

# %%
actions[np.argmax(res)]
# Out:
# 'hello'

# %%
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
model.fit(X_train, y_train, epochs=2000, callbacks=[tb_callback])
# Out:
# Epoch 1/2000
# 3/3 [==============================] - 3s 95ms/step - loss: 1.5197 - categorical_accuracy: 0.4691
# Epoch 2/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 12.4692 - categorical_accuracy: 0.2593
# Epoch 3/2000
# 3/3 [==============================] - 0s 104ms/step - loss: 9.7937 - categorical_accuracy: 0.4074
# Epoch 4/2000
# 3/3 [==============================] - 0s 105ms/step - loss: 11.8405 - categorical_accuracy: 0.3086
# Epoch 5/2000
# 3/3 [==============================] - 0s 110ms/step - loss: 6.7078 - categorical_accuracy: 0.3580
# Epoch 6/2000
# 3/3 [==============================] - 0s 99ms/step - loss: 5.9515 - categorical_accuracy: 0.2222
# Epoch 7/2000
# 3/3 [==============================] - 0s 129ms/step - loss: 6.3667 - categorical_accuracy: 0.3210
# Epoch 8/2000
# 3/3 [==============================] - 0s 101ms/step - loss: 6.1553 - categorical_accuracy: 0.2963
# Epoch 9/2000
# 3/3 [==============================] - 0s 99ms/step - loss: 5.4033 - categorical_accuracy: 0.2963
# Epoch 10/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 4.2213 - categorical_accuracy: 0.3333
# Epoch 11/2000
# 3/3 [==============================] - 0s 100ms/step - loss: 2.5120 - categorical_accuracy: 0.3580
# Epoch 12/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 2.4457 - categorical_accuracy: 0.3704
# Epoch 13/2000
# 3/3 [==============================] - 0s 101ms/step - loss: 1.9693 - categorical_accuracy: 0.3704
# Epoch 14/2000
# 3/3 [==============================] - 0s 112ms/step - loss: 2.6389 - categorical_accuracy: 0.3457
# Epoch 15/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 2.5791 - categorical_accuracy: 0.4938
# Epoch 16/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 10.4445 - categorical_accuracy: 0.3086
# Epoch 17/2000
# 3/3 [==============================] - 0s 112ms/step - loss: 2.6443 - categorical_accuracy: 0.3457
# Epoch 18/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 2.5409 - categorical_accuracy: 0.3333
# Epoch 19/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 3.1427 - categorical_accuracy: 0.3704
# Epoch 20/2000
# 3/3 [==============================] - 0s 107ms/step - loss: 14.2469 - categorical_accuracy: 0.3210
# Epoch 21/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 24.6109 - categorical_accuracy: 0.3333
# Epoch 22/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 9.8887 - categorical_accuracy: 0.3704
# Epoch 23/2000
# 3/3 [==============================] - 0s 100ms/step - loss: 5.3159 - categorical_accuracy: 0.3951
# Epoch 24/2000
# 3/3 [==============================] - 0s 99ms/step - loss: 6.7697 - categorical_accuracy: 0.4568
# Epoch 25/2000
# 3/3 [==============================] - 0s 101ms/step - loss: 9.6116 - categorical_accuracy: 0.2840
# Epoch 26/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 6.8120 - categorical_accuracy: 0.2593
# Epoch 27/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 6.5217 - categorical_accuracy: 0.3333
# Epoch 28/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 3.6345 - categorical_accuracy: 0.4198
# Epoch 29/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 10.5250 - categorical_accuracy: 0.3827
# Epoch 30/2000
# 3/3 [==============================] - 0s 101ms/step - loss: 11.6390 - categorical_accuracy: 0.3704
# Epoch 31/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 26.4648 - categorical_accuracy: 0.3086
# Epoch 32/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 14.4496 - categorical_accuracy: 0.3704
# Epoch 33/2000
# 3/3 [==============================] - 0s 99ms/step - loss: 23.6547 - categorical_accuracy: 0.3580
# Epoch 34/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 46.2223 - categorical_accuracy: 0.3704
# Epoch 35/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 20.0816 - categorical_accuracy: 0.2840
# Epoch 36/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 18.8394 - categorical_accuracy: 0.2593
# Epoch 37/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 16.3785 - categorical_accuracy: 0.3580
# Epoch 38/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 9.2307 - categorical_accuracy: 0.2716
# Epoch 39/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 15.5249 - categorical_accuracy: 0.2840
# Epoch 40/2000
# 3/3 [==============================] - 0s 102ms/step - loss: 18.6903 - categorical_accuracy: 0.3704
# Epoch 41/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 10.1457 - categorical_accuracy: 0.3210
# Epoch 42/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 22.6478 - categorical_accuracy: 0.2840
# Epoch 43/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 7.0086 - categorical_accuracy: 0.3333
# Epoch 44/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 5.2699 - categorical_accuracy: 0.3457
# Epoch 45/2000
# 3/3 [==============================] - 0s 100ms/step - loss: 3.2278 - categorical_accuracy: 0.3827
# Epoch 46/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 3.5149 - categorical_accuracy: 0.3580
# Epoch 47/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 2.3627 - categorical_accuracy: 0.3827
# Epoch 48/2000
# 3/3 [==============================] - 0s 99ms/step - loss: 1.3537 - categorical_accuracy: 0.2963
# Epoch 49/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 1.1821 - categorical_accuracy: 0.2840
# Epoch 50/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 0.9350 - categorical_accuracy: 0.5432
# Epoch 51/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 0.9583 - categorical_accuracy: 0.4444
# Epoch 52/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 1.1211 - categorical_accuracy: 0.4568
# Epoch 53/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 0.9874 - categorical_accuracy: 0.3580
# Epoch 54/2000
# 3/3 [==============================] - 0s 102ms/step - loss: 0.9184 - categorical_accuracy: 0.5062
# Epoch 55/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 0.8110 - categorical_accuracy: 0.5802
# Epoch 56/2000
# 3/3 [==============================] - 0s 100ms/step - loss: 0.9191 - categorical_accuracy: 0.5185
# Epoch 57/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 0.8856 - categorical_accuracy: 0.5432
# Epoch 58/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 0.9545 - categorical_accuracy: 0.5309
# Epoch 59/2000
# 3/3 [==============================] - 0s 104ms/step - loss: 0.8648 - categorical_accuracy: 0.6296
# Epoch 60/2000
# 3/3 [==============================] - 0s 99ms/step - loss: 0.8384 - categorical_accuracy: 0.6667
# Epoch 61/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 0.8883 - categorical_accuracy: 0.6296
# Epoch 62/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 0.9919 - categorical_accuracy: 0.4691
# Epoch 63/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 0.8802 - categorical_accuracy: 0.6420
# Epoch 64/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.7723 - categorical_accuracy: 0.6790
# Epoch 65/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.7255 - categorical_accuracy: 0.6667
# Epoch 66/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 0.7137 - categorical_accuracy: 0.6667
# Epoch 67/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 0.6702 - categorical_accuracy: 0.7407
# Epoch 68/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 0.6800 - categorical_accuracy: 0.7407
# Epoch 69/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.6445 - categorical_accuracy: 0.7531
# Epoch 70/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 0.5814 - categorical_accuracy: 0.7654
# Epoch 71/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 0.5290 - categorical_accuracy: 0.8025
# Epoch 72/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.5529 - categorical_accuracy: 0.7778
# Epoch 73/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 0.6062 - categorical_accuracy: 0.7531
# Epoch 74/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.6261 - categorical_accuracy: 0.7654
# Epoch 75/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 0.6196 - categorical_accuracy: 0.7284
# Epoch 76/2000
# 3/3 [==============================] - 0s 169ms/step - loss: 0.6146 - categorical_accuracy: 0.7778
# Epoch 77/2000
# 3/3 [==============================] - 0s 109ms/step - loss: 0.5494 - categorical_accuracy: 0.7778
# Epoch 78/2000
# 3/3 [==============================] - 0s 116ms/step - loss: 0.5195 - categorical_accuracy: 0.8025
# Epoch 79/2000
# 3/3 [==============================] - 0s 104ms/step - loss: 0.5355 - categorical_accuracy: 0.7160
# Epoch 80/2000
# 3/3 [==============================] - 0s 109ms/step - loss: 0.4681 - categorical_accuracy: 0.8642
# Epoch 81/2000
# 3/3 [==============================] - 0s 117ms/step - loss: 0.4240 - categorical_accuracy: 0.8642
# Epoch 82/2000
# 3/3 [==============================] - 0s 122ms/step - loss: 0.5189 - categorical_accuracy: 0.8025
# Epoch 83/2000
# 3/3 [==============================] - 0s 117ms/step - loss: 0.4309 - categorical_accuracy: 0.8519
# Epoch 84/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 0.4389 - categorical_accuracy: 0.8765
# Epoch 85/2000
# 3/3 [==============================] - 0s 99ms/step - loss: 0.3464 - categorical_accuracy: 0.9012
# Epoch 86/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.4098 - categorical_accuracy: 0.8519
# Epoch 87/2000
# 3/3 [==============================] - 0s 83ms/step - loss: 0.5072 - categorical_accuracy: 0.7901
# Epoch 88/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.3313 - categorical_accuracy: 0.8765
# Epoch 89/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 0.3394 - categorical_accuracy: 0.8765
# Epoch 90/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.3250 - categorical_accuracy: 0.8642
# Epoch 91/2000
# 3/3 [==============================] - 0s 112ms/step - loss: 0.3661 - categorical_accuracy: 0.8395
# Epoch 92/2000
# 3/3 [==============================] - 0s 120ms/step - loss: 0.3090 - categorical_accuracy: 0.8642
# Epoch 93/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 0.3439 - categorical_accuracy: 0.8642
# Epoch 94/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.4722 - categorical_accuracy: 0.7901
# Epoch 95/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 0.4150 - categorical_accuracy: 0.8272
# Epoch 96/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 0.5499 - categorical_accuracy: 0.7531
# Epoch 97/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 0.6735 - categorical_accuracy: 0.7037
# Epoch 98/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 0.7998 - categorical_accuracy: 0.7654
# Epoch 99/2000
# 3/3 [==============================] - 0s 104ms/step - loss: 0.4189 - categorical_accuracy: 0.8395
# Epoch 100/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.6015 - categorical_accuracy: 0.7531
# Epoch 101/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.4563 - categorical_accuracy: 0.8148
# Epoch 102/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 0.4306 - categorical_accuracy: 0.8272
# Epoch 103/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 0.5295 - categorical_accuracy: 0.7901
# Epoch 104/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 0.3613 - categorical_accuracy: 0.8395
# Epoch 105/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 0.4514 - categorical_accuracy: 0.8025
# Epoch 106/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.3723 - categorical_accuracy: 0.8395
# Epoch 107/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 0.3241 - categorical_accuracy: 0.8642
# Epoch 108/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 0.3060 - categorical_accuracy: 0.8889
# Epoch 109/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 0.2789 - categorical_accuracy: 0.8889
# Epoch 110/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 0.3202 - categorical_accuracy: 0.8519
# Epoch 111/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 0.3408 - categorical_accuracy: 0.8519
# Epoch 112/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 0.3173 - categorical_accuracy: 0.8519
# Epoch 113/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 0.2481 - categorical_accuracy: 0.9383
# Epoch 114/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 0.3059 - categorical_accuracy: 0.8765
# Epoch 115/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 0.2500 - categorical_accuracy: 0.9136
# Epoch 116/2000
# 3/3 [==============================] - 0s 100ms/step - loss: 0.2520 - categorical_accuracy: 0.9259
# Epoch 117/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.2483 - categorical_accuracy: 0.9136
# Epoch 118/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 0.2265 - categorical_accuracy: 0.9259
# Epoch 119/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.2705 - categorical_accuracy: 0.9136
# Epoch 120/2000
# 3/3 [==============================] - 0s 84ms/step - loss: 0.3956 - categorical_accuracy: 0.8272
# Epoch 121/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.3451 - categorical_accuracy: 0.8642
# Epoch 122/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.3821 - categorical_accuracy: 0.8025
# Epoch 123/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 0.3734 - categorical_accuracy: 0.8765
# Epoch 124/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 0.3399 - categorical_accuracy: 0.8148
# Epoch 125/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.3529 - categorical_accuracy: 0.8642
# Epoch 126/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 0.4620 - categorical_accuracy: 0.8395
# Epoch 127/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.4808 - categorical_accuracy: 0.7901
# Epoch 128/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 0.4936 - categorical_accuracy: 0.7654
# Epoch 129/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.4583 - categorical_accuracy: 0.7654
# Epoch 130/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 0.3629 - categorical_accuracy: 0.8395
# Epoch 131/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.3377 - categorical_accuracy: 0.8395
# Epoch 132/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 0.5019 - categorical_accuracy: 0.7531
# Epoch 133/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.4733 - categorical_accuracy: 0.8148
# Epoch 134/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 0.3706 - categorical_accuracy: 0.8395
# Epoch 135/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.3434 - categorical_accuracy: 0.8642
# Epoch 136/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 0.3342 - categorical_accuracy: 0.8272
# Epoch 137/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.3707 - categorical_accuracy: 0.8519
# Epoch 138/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 0.3244 - categorical_accuracy: 0.8642
# Epoch 139/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 0.2759 - categorical_accuracy: 0.8889
# Epoch 140/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.2928 - categorical_accuracy: 0.8889
# Epoch 141/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 0.2863 - categorical_accuracy: 0.8765
# Epoch 142/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 0.2520 - categorical_accuracy: 0.9136
# Epoch 143/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.2321 - categorical_accuracy: 0.9136
# Epoch 144/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 0.2221 - categorical_accuracy: 0.9012
# Epoch 145/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 0.2470 - categorical_accuracy: 0.9136
# Epoch 146/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 0.2018 - categorical_accuracy: 0.9136
# Epoch 147/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 0.2308 - categorical_accuracy: 0.9012
# Epoch 148/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 0.2485 - categorical_accuracy: 0.8765
# Epoch 149/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.2936 - categorical_accuracy: 0.8889
# Epoch 150/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.2208 - categorical_accuracy: 0.9012
# Epoch 151/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 0.1971 - categorical_accuracy: 0.9383
# Epoch 152/2000
# 3/3 [==============================] - 0s 100ms/step - loss: 0.3242 - categorical_accuracy: 0.8765
# Epoch 153/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.2304 - categorical_accuracy: 0.9383
# Epoch 154/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.1891 - categorical_accuracy: 0.9383
# Epoch 155/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 0.2193 - categorical_accuracy: 0.8889
# Epoch 156/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.2462 - categorical_accuracy: 0.9012
# Epoch 157/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.2132 - categorical_accuracy: 0.9136
# Epoch 158/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 0.2555 - categorical_accuracy: 0.8889
# Epoch 159/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 0.2821 - categorical_accuracy: 0.8889
# Epoch 160/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 0.3659 - categorical_accuracy: 0.8272
# Epoch 161/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 0.9475 - categorical_accuracy: 0.6914
# Epoch 162/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.6406 - categorical_accuracy: 0.7284
# Epoch 163/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 0.8236 - categorical_accuracy: 0.7037
# Epoch 164/2000
# 3/3 [==============================] - 0s 108ms/step - loss: 0.8010 - categorical_accuracy: 0.6914
# Epoch 165/2000
# 3/3 [==============================] - 0s 101ms/step - loss: 0.4832 - categorical_accuracy: 0.7654
# Epoch 166/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 0.4443 - categorical_accuracy: 0.8272
# Epoch 167/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 0.3491 - categorical_accuracy: 0.8765
# Epoch 168/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 0.4258 - categorical_accuracy: 0.8395
# Epoch 169/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 0.3686 - categorical_accuracy: 0.8642
# Epoch 170/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 0.3082 - categorical_accuracy: 0.9136
# Epoch 171/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.3343 - categorical_accuracy: 0.9012
# Epoch 172/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 0.2760 - categorical_accuracy: 0.9012
# Epoch 173/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.2662 - categorical_accuracy: 0.9259
# Epoch 174/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.2708 - categorical_accuracy: 0.9136
# Epoch 175/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 0.2275 - categorical_accuracy: 0.9383
# Epoch 176/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.2454 - categorical_accuracy: 0.9012
# Epoch 177/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 0.2360 - categorical_accuracy: 0.9136
# Epoch 178/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.2010 - categorical_accuracy: 0.9259
# Epoch 179/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.2166 - categorical_accuracy: 0.9506
# Epoch 180/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 0.2066 - categorical_accuracy: 0.9136
# Epoch 181/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.2073 - categorical_accuracy: 0.9383
# Epoch 182/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.2066 - categorical_accuracy: 0.9012
# Epoch 183/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.2681 - categorical_accuracy: 0.8889
# Epoch 184/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 0.3334 - categorical_accuracy: 0.8519
# Epoch 185/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 0.2897 - categorical_accuracy: 0.8765
# Epoch 186/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.2364 - categorical_accuracy: 0.8642
# Epoch 187/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 0.2603 - categorical_accuracy: 0.8889
# Epoch 188/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 0.2988 - categorical_accuracy: 0.8519
# Epoch 189/2000
# 3/3 [==============================] - 0s 104ms/step - loss: 0.2179 - categorical_accuracy: 0.9136
# Epoch 190/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 0.2110 - categorical_accuracy: 0.9259
# Epoch 191/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.2081 - categorical_accuracy: 0.9012
# Epoch 192/2000
# 3/3 [==============================] - 0s 105ms/step - loss: 0.2027 - categorical_accuracy: 0.9136
# Epoch 193/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 0.1770 - categorical_accuracy: 0.9383
# Epoch 194/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 0.1683 - categorical_accuracy: 0.9259
# Epoch 195/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 0.2002 - categorical_accuracy: 0.9136
# Epoch 196/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 0.1974 - categorical_accuracy: 0.9259
# Epoch 197/2000
# 3/3 [==============================] - 0s 82ms/step - loss: 0.2699 - categorical_accuracy: 0.9259
# Epoch 198/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 0.1813 - categorical_accuracy: 0.9136
# Epoch 199/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 0.1955 - categorical_accuracy: 0.9383
# Epoch 200/2000
# 3/3 [==============================] - 0s 84ms/step - loss: 0.4934 - categorical_accuracy: 0.8025
# Epoch 201/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.2813 - categorical_accuracy: 0.8765
# Epoch 202/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.2659 - categorical_accuracy: 0.8765
# Epoch 203/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.2354 - categorical_accuracy: 0.9383
# Epoch 204/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.2604 - categorical_accuracy: 0.9012
# Epoch 205/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 0.3281 - categorical_accuracy: 0.8765
# Epoch 206/2000
# 3/3 [==============================] - 0s 102ms/step - loss: 0.2081 - categorical_accuracy: 0.9136
# Epoch 207/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 0.2013 - categorical_accuracy: 0.9259
# Epoch 208/2000
# 3/3 [==============================] - 0s 100ms/step - loss: 0.1638 - categorical_accuracy: 0.9383
# Epoch 209/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 0.1508 - categorical_accuracy: 0.9506
# Epoch 210/2000
# 3/3 [==============================] - 0s 107ms/step - loss: 0.1624 - categorical_accuracy: 0.9506
# Epoch 211/2000
# 3/3 [==============================] - 0s 103ms/step - loss: 0.1618 - categorical_accuracy: 0.9259
# Epoch 212/2000
# 3/3 [==============================] - 0s 129ms/step - loss: 0.1975 - categorical_accuracy: 0.9259
# Epoch 213/2000
# 3/3 [==============================] - 0s 105ms/step - loss: 0.1720 - categorical_accuracy: 0.9136
# Epoch 214/2000
# 3/3 [==============================] - 0s 111ms/step - loss: 0.1821 - categorical_accuracy: 0.9259
# Epoch 215/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 0.2696 - categorical_accuracy: 0.8642
# Epoch 216/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 0.2355 - categorical_accuracy: 0.9012
# Epoch 217/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.3476 - categorical_accuracy: 0.8148
# Epoch 218/2000
# 3/3 [==============================] - 0s 115ms/step - loss: 0.4040 - categorical_accuracy: 0.8642
# Epoch 219/2000
# 3/3 [==============================] - 0s 99ms/step - loss: 0.3199 - categorical_accuracy: 0.8642
# Epoch 220/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 0.2412 - categorical_accuracy: 0.9012
# Epoch 221/2000
# 3/3 [==============================] - 0s 102ms/step - loss: 0.2329 - categorical_accuracy: 0.9259
# Epoch 222/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.1806 - categorical_accuracy: 0.9506
# Epoch 223/2000
# 3/3 [==============================] - 0s 105ms/step - loss: 0.2146 - categorical_accuracy: 0.9259
# Epoch 224/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.1742 - categorical_accuracy: 0.9506
# Epoch 225/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.1463 - categorical_accuracy: 0.9506
# Epoch 226/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 0.1317 - categorical_accuracy: 0.9630
# Epoch 227/2000
# 3/3 [==============================] - 0s 103ms/step - loss: 0.1303 - categorical_accuracy: 0.9506
# Epoch 228/2000
# 3/3 [==============================] - 0s 139ms/step - loss: 0.1180 - categorical_accuracy: 0.9506
# Epoch 229/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 0.1064 - categorical_accuracy: 0.9630
# Epoch 230/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 0.1023 - categorical_accuracy: 0.9630
# Epoch 231/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 0.1254 - categorical_accuracy: 0.9506
# Epoch 232/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.2542 - categorical_accuracy: 0.9136
# Epoch 233/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 0.1364 - categorical_accuracy: 0.9383
# Epoch 234/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 0.1825 - categorical_accuracy: 0.9259
# Epoch 235/2000
# 3/3 [==============================] - 0s 84ms/step - loss: 0.1242 - categorical_accuracy: 0.9630
# Epoch 236/2000
# 3/3 [==============================] - 0s 99ms/step - loss: 0.1404 - categorical_accuracy: 0.9630
# Epoch 237/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.1501 - categorical_accuracy: 0.9383
# Epoch 238/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 0.1200 - categorical_accuracy: 0.9383
# Epoch 239/2000
# 3/3 [==============================] - 0s 108ms/step - loss: 0.1616 - categorical_accuracy: 0.9383
# Epoch 240/2000
# 3/3 [==============================] - 0s 120ms/step - loss: 0.1757 - categorical_accuracy: 0.9259
# Epoch 241/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 0.1503 - categorical_accuracy: 0.9506
# Epoch 242/2000
# 3/3 [==============================] - 0s 83ms/step - loss: 0.2469 - categorical_accuracy: 0.9012
# Epoch 243/2000
# 3/3 [==============================] - 0s 82ms/step - loss: 0.2255 - categorical_accuracy: 0.9136
# Epoch 244/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 0.7482 - categorical_accuracy: 0.6543
# Epoch 245/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 0.3461 - categorical_accuracy: 0.8395
# Epoch 246/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 0.4202 - categorical_accuracy: 0.7531
# Epoch 247/2000
# 3/3 [==============================] - 0s 99ms/step - loss: 0.4502 - categorical_accuracy: 0.8395
# Epoch 248/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 0.2724 - categorical_accuracy: 0.9136
# Epoch 249/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.3469 - categorical_accuracy: 0.9136
# Epoch 250/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 0.3705 - categorical_accuracy: 0.8025
# Epoch 251/2000
# 3/3 [==============================] - 0s 84ms/step - loss: 0.2947 - categorical_accuracy: 0.8642
# Epoch 252/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.2974 - categorical_accuracy: 0.9012
# Epoch 253/2000
# 3/3 [==============================] - 0s 127ms/step - loss: 0.2653 - categorical_accuracy: 0.9259
# Epoch 254/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 0.2489 - categorical_accuracy: 0.8889
# Epoch 255/2000
# 3/3 [==============================] - 0s 84ms/step - loss: 0.2141 - categorical_accuracy: 0.9259
# Epoch 256/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 0.2005 - categorical_accuracy: 0.9383
# Epoch 257/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 0.1718 - categorical_accuracy: 0.9383
# Epoch 258/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 0.1432 - categorical_accuracy: 0.9630
# Epoch 259/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 0.1845 - categorical_accuracy: 0.9506
# Epoch 260/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 0.1986 - categorical_accuracy: 0.9259
# Epoch 261/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 0.1200 - categorical_accuracy: 0.9630
# Epoch 262/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.1474 - categorical_accuracy: 0.9506
# Epoch 263/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 0.1707 - categorical_accuracy: 0.9383
# Epoch 264/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 0.1428 - categorical_accuracy: 0.9383
# Epoch 265/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 0.1277 - categorical_accuracy: 0.9506
# Epoch 266/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.1051 - categorical_accuracy: 0.9630
# Epoch 267/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 0.1771 - categorical_accuracy: 0.9259
# Epoch 268/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.2072 - categorical_accuracy: 0.9383
# Epoch 269/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 0.1571 - categorical_accuracy: 0.9506
# Epoch 270/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 0.1154 - categorical_accuracy: 0.9630
# Epoch 271/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.1517 - categorical_accuracy: 0.9383
# Epoch 272/2000
# 3/3 [==============================] - 0s 101ms/step - loss: 0.1012 - categorical_accuracy: 0.9630
# Epoch 273/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.0935 - categorical_accuracy: 0.9630
# Epoch 274/2000
# 3/3 [==============================] - 0s 126ms/step - loss: 0.0867 - categorical_accuracy: 0.9630
# Epoch 275/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 0.1635 - categorical_accuracy: 0.9383
# Epoch 276/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.2537 - categorical_accuracy: 0.8765
# Epoch 277/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.1844 - categorical_accuracy: 0.9136
# Epoch 278/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 0.1789 - categorical_accuracy: 0.9259
# Epoch 279/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.0976 - categorical_accuracy: 0.9506
# Epoch 280/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.1040 - categorical_accuracy: 0.9506
# Epoch 281/2000
# 3/3 [==============================] - 0s 99ms/step - loss: 0.1086 - categorical_accuracy: 0.9630
# Epoch 282/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.0774 - categorical_accuracy: 0.9877
# Epoch 283/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 0.0695 - categorical_accuracy: 0.9877
# Epoch 284/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.0701 - categorical_accuracy: 0.9877
# Epoch 285/2000
# 3/3 [==============================] - 0s 113ms/step - loss: 0.0585 - categorical_accuracy: 0.9877
# Epoch 286/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.0800 - categorical_accuracy: 0.9630
# Epoch 287/2000
# 3/3 [==============================] - 0s 138ms/step - loss: 0.0737 - categorical_accuracy: 0.9753
# Epoch 288/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.0660 - categorical_accuracy: 0.9753
# Epoch 289/2000
# 3/3 [==============================] - 0s 82ms/step - loss: 0.0729 - categorical_accuracy: 0.9753
# Epoch 290/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.0600 - categorical_accuracy: 0.9753
# Epoch 291/2000
# 3/3 [==============================] - 0s 100ms/step - loss: 0.0849 - categorical_accuracy: 0.9506
# Epoch 292/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 0.2969 - categorical_accuracy: 0.9136
# Epoch 293/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.1517 - categorical_accuracy: 0.9383
# Epoch 294/2000
# 3/3 [==============================] - 0s 103ms/step - loss: 0.4234 - categorical_accuracy: 0.8765
# Epoch 295/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 0.2618 - categorical_accuracy: 0.9012
# Epoch 296/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 0.2415 - categorical_accuracy: 0.9012
# Epoch 297/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 0.1511 - categorical_accuracy: 0.9630
# Epoch 298/2000
# 3/3 [==============================] - 0s 83ms/step - loss: 0.1810 - categorical_accuracy: 0.9383
# Epoch 299/2000
# 3/3 [==============================] - 0s 81ms/step - loss: 0.1885 - categorical_accuracy: 0.9259
# Epoch 300/2000
# 3/3 [==============================] - 0s 81ms/step - loss: 0.1505 - categorical_accuracy: 0.9259
# Epoch 301/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.2191 - categorical_accuracy: 0.8889
# Epoch 302/2000
# 3/3 [==============================] - 0s 102ms/step - loss: 0.2568 - categorical_accuracy: 0.8642
# Epoch 303/2000
# 3/3 [==============================] - 0s 121ms/step - loss: 0.2485 - categorical_accuracy: 0.9136
# Epoch 304/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 1.2652 - categorical_accuracy: 0.6420
# Epoch 305/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 0.6398 - categorical_accuracy: 0.7778
# Epoch 306/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 1.0463 - categorical_accuracy: 0.6420
# Epoch 307/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.6733 - categorical_accuracy: 0.6914
# Epoch 308/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.7891 - categorical_accuracy: 0.6420
# Epoch 309/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.7802 - categorical_accuracy: 0.6296
# Epoch 310/2000
# 3/3 [==============================] - 0s 101ms/step - loss: 0.7423 - categorical_accuracy: 0.6049
# Epoch 311/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.6467 - categorical_accuracy: 0.7407
# Epoch 312/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 0.5981 - categorical_accuracy: 0.7160
# Epoch 313/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.5251 - categorical_accuracy: 0.7654
# Epoch 314/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 0.5068 - categorical_accuracy: 0.7160
# Epoch 315/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 0.4801 - categorical_accuracy: 0.7407
# Epoch 316/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.4710 - categorical_accuracy: 0.8272
# Epoch 317/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 0.4348 - categorical_accuracy: 0.8025
# Epoch 318/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 0.4605 - categorical_accuracy: 0.7778
# Epoch 319/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 0.3980 - categorical_accuracy: 0.9259
# Epoch 320/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.3803 - categorical_accuracy: 0.9136
# Epoch 321/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 0.3592 - categorical_accuracy: 0.9012
# Epoch 322/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.3475 - categorical_accuracy: 0.8765
# Epoch 323/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.3366 - categorical_accuracy: 0.8642
# Epoch 324/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 0.3229 - categorical_accuracy: 0.8889
# Epoch 325/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 0.3078 - categorical_accuracy: 0.8889
# Epoch 326/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 0.2977 - categorical_accuracy: 0.8889
# Epoch 327/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 0.2849 - categorical_accuracy: 0.8889
# Epoch 328/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.2678 - categorical_accuracy: 0.9506
# Epoch 329/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 0.2463 - categorical_accuracy: 0.9506
# Epoch 330/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 0.2569 - categorical_accuracy: 0.9259
# Epoch 331/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 0.2073 - categorical_accuracy: 0.9753
# Epoch 332/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.1911 - categorical_accuracy: 0.9630
# Epoch 333/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 0.2144 - categorical_accuracy: 0.9259
# Epoch 334/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 0.1986 - categorical_accuracy: 0.9136
# Epoch 335/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.2509 - categorical_accuracy: 0.9012
# Epoch 336/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 0.1953 - categorical_accuracy: 0.9506
# Epoch 337/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 0.1449 - categorical_accuracy: 0.9753
# Epoch 338/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.1463 - categorical_accuracy: 0.9506
# Epoch 339/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.1350 - categorical_accuracy: 0.9630
# Epoch 340/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 0.1323 - categorical_accuracy: 0.9506
# Epoch 341/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 0.2454 - categorical_accuracy: 0.9136
# Epoch 342/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.3593 - categorical_accuracy: 0.8889
# Epoch 343/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 0.3309 - categorical_accuracy: 0.9012
# Epoch 344/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 0.2623 - categorical_accuracy: 0.8765
# Epoch 345/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 0.3319 - categorical_accuracy: 0.9012
# Epoch 346/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 0.2832 - categorical_accuracy: 0.8889
# Epoch 347/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 0.3725 - categorical_accuracy: 0.8272
# Epoch 348/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 0.2731 - categorical_accuracy: 0.8765
# Epoch 349/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.2054 - categorical_accuracy: 0.9136
# Epoch 350/2000
# 3/3 [==============================] - 0s 83ms/step - loss: 0.1760 - categorical_accuracy: 0.9136
# Epoch 351/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 0.2625 - categorical_accuracy: 0.9136
# Epoch 352/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 0.2453 - categorical_accuracy: 0.9012
# Epoch 353/2000
# 3/3 [==============================] - 0s 95ms/step - loss: 0.5079 - categorical_accuracy: 0.7901
# Epoch 354/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 0.3517 - categorical_accuracy: 0.8148
# Epoch 355/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.2171 - categorical_accuracy: 0.9012
# Epoch 356/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 0.1738 - categorical_accuracy: 0.9383
# Epoch 357/2000
# 3/3 [==============================] - 0s 84ms/step - loss: 0.1913 - categorical_accuracy: 0.9383
# Epoch 358/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 0.1399 - categorical_accuracy: 0.9753
# Epoch 359/2000
# 3/3 [==============================] - 0s 99ms/step - loss: 0.1636 - categorical_accuracy: 0.9506
# Epoch 360/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 0.1246 - categorical_accuracy: 0.9630
# Epoch 361/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 0.1206 - categorical_accuracy: 0.9630
# Epoch 362/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.0772 - categorical_accuracy: 0.9877
# Epoch 363/2000
# 3/3 [==============================] - 0s 100ms/step - loss: 0.0826 - categorical_accuracy: 0.9753
# Epoch 364/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.0839 - categorical_accuracy: 0.9877
# Epoch 365/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.0845 - categorical_accuracy: 0.9753
# Epoch 366/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 0.0718 - categorical_accuracy: 0.9877
# Epoch 367/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 0.0534 - categorical_accuracy: 0.9877
# Epoch 368/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 0.0548 - categorical_accuracy: 1.0000
# Epoch 369/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.0523 - categorical_accuracy: 1.0000
# Epoch 370/2000
# 3/3 [==============================] - 0s 89ms/step - loss: 0.0402 - categorical_accuracy: 0.9877
# Epoch 371/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 0.0494 - categorical_accuracy: 0.9877
# Epoch 372/2000
# 3/3 [==============================] - 0s 90ms/step - loss: 0.0698 - categorical_accuracy: 0.9630
# Epoch 373/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 0.3399 - categorical_accuracy: 0.8642
# Epoch 374/2000
# 3/3 [==============================] - 0s 88ms/step - loss: 0.2548 - categorical_accuracy: 0.8395
# Epoch 375/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 0.1863 - categorical_accuracy: 0.9383
# Epoch 376/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 0.1175 - categorical_accuracy: 0.9506
# Epoch 377/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 0.1208 - categorical_accuracy: 0.9506
# Epoch 378/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 0.0790 - categorical_accuracy: 0.9877
# Epoch 379/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 0.1156 - categorical_accuracy: 0.9506
# Epoch 380/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 0.0656 - categorical_accuracy: 0.9877
# Epoch 381/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 0.0560 - categorical_accuracy: 0.9877
# Epoch 382/2000
# 3/3 [==============================] - 0s 85ms/step - loss: 0.0527 - categorical_accuracy: 1.0000
# Epoch 383/2000
# 3/3 [==============================] - 0s 86ms/step - loss: 0.0567 - categorical_accuracy: 0.9877
# Epoch 384/2000
# 3/3 [==============================] - 0s 84ms/step - loss: 0.0375 - categorical_accuracy: 1.0000
# Epoch 385/2000
# 3/3 [==============================] - 0s 92ms/step - loss: 0.0375 - categorical_accuracy: 1.0000
# Epoch 386/2000
# 3/3 [==============================] - 0s 84ms/step - loss: 0.0315 - categorical_accuracy: 1.0000
# Epoch 387/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.0362 - categorical_accuracy: 0.9877
# Epoch 388/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 0.3929 - categorical_accuracy: 0.8519
# Epoch 389/2000
# 3/3 [==============================] - 0s 94ms/step - loss: 0.5485 - categorical_accuracy: 0.8025
# Epoch 390/2000
# 3/3 [==============================] - 0s 97ms/step - loss: 0.6173 - categorical_accuracy: 0.7778
# Epoch 391/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 0.3510 - categorical_accuracy: 0.8519
# Epoch 392/2000
# 3/3 [==============================] - 0s 98ms/step - loss: 0.3097 - categorical_accuracy: 0.8889
# Epoch 393/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 0.2637 - categorical_accuracy: 0.9383
# Epoch 394/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 0.1874 - categorical_accuracy: 0.9259
# Epoch 395/2000
# 3/3 [==============================] - 0s 99ms/step - loss: 0.1120 - categorical_accuracy: 0.9877
# Epoch 396/2000
# 3/3 [==============================] - 0s 83ms/step - loss: 0.1260 - categorical_accuracy: 0.9630
# Epoch 397/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 0.1094 - categorical_accuracy: 0.9877
# Epoch 398/2000
# 3/3 [==============================] - 0s 87ms/step - loss: 0.1625 - categorical_accuracy: 0.9630
# Epoch 399/2000
# 3/3 [==============================] - 0s 96ms/step - loss: 0.1775 - categorical_accuracy: 0.9383
# Epoch 400/2000
# 3/3 [==============================] - 0s 105ms/step - loss: 0.1308 - categorical_accuracy: 0.9753
# Epoch 401/2000
# 3/3 [==============================] - 0s 91ms/step - loss: 0.2092 - categorical_accuracy: 0.9012
# Epoch 402/2000
# 3/3 [==============================] - 0s 93ms/step - loss: 0.1462 - categorical_accuracy: 0.9383
# Epoch 403/2000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13112/647883075.py in <module>
# ----> 1 model.fit(X_train, y_train, epochs=2000, callbacks=[tb_callback])
#
# D:\All Apps\anaconda3\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# D:\All Apps\anaconda3\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1382                 _r=1):
#    1383               callbacks.on_train_batch_begin(step)
# -> 1384               tmp_logs = self.train_function(iterator)
#    1385               if data_handler.should_sync:
#    1386                 context.async_wait()
#
# D:\All Apps\anaconda3\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# D:\All Apps\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     913
#     914       with OptionalXlaContext(self._jit_compile):
# --> 915         result = self._call(*args, **kwds)
#     916
#     917       new_tracing_count = self.experimental_get_tracing_count()
#
# D:\All Apps\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     945       # In this case we have created variables on the first call, so we run the
#     946       # defunned version which is guaranteed to never create variables.
# --> 947       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948     elif self._stateful_fn is not None:
#     949       # Release the lock early so that multiple threads can perform the call
#
# D:\All Apps\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    2954       (graph_function,
#    2955        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2956     return graph_function._call_flat(
#    2957         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2958
#
# D:\All Apps\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1851         and executing_eagerly):
#    1852       # No tape is watching; skip to running the function.
# -> 1853       return self._build_call_outputs(self._inference_function.call(
#    1854           ctx, args, cancellation_manager=cancellation_manager))
#    1855     forward_backward = self._select_forward_and_backward_functions(
#
# D:\All Apps\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     497       with _InterpolateFunctionError(self):
#     498         if cancellation_manager is None:
# --> 499           outputs = execute.execute(
#     500               str(self.signature.name),
#     501               num_outputs=self._num_outputs,
#
# D:\All Apps\anaconda3\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52   try:
#      53     ctx.ensure_initialized()
# ---> 54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 30, 64)            442112
#
#  lstm_1 (LSTM)               (None, 30, 128)           98816
#
#  lstm_2 (LSTM)               (None, 64)                49408
#
#  dense (Dense)               (None, 64)                4160
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 3)                 99
#
# =================================================================
# Total params: 596,675
# Trainable params: 596,675
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 8. Make Predictions

# %%
res = model.predict(X_test)

# %%
actions[np.argmax(res[0])]
# Out:
# 'iloveyou'

# %%
actions[np.argmax(y_test[4])]
# Out:
# 'iloveyou'

# %% [markdown]
# # 9. Save Weights

# %%
model.save('action.h5')

# %%
del model

# %%
model.load_weights('action.h5')

# %% [markdown]
# # 10. Evaluation using Confusion Matrix and Accuracy

# %%
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score

# %%
yhat = model.predict(X_test)

# %%
ytrue = np.argmax(y_test, axis=1).tolist()
yhat = np.argmax(yhat, axis=1).tolist()

# %%
multilabel_confusion_matrix(ytrue, yhat)
# Out:
# array([[[6, 0],
#         [0, 3]],
#
#        [[7, 0],
#         [0, 2]],
#
#        [[5, 0],
#         [0, 4]]], dtype=int64)

# %%
accuracy_score(ytrue, yhat)
# Out:
# 1.0

# %% [markdown]
# # 11. Test in Real Time

# %%
colors = [(245,117,16), (117,245,16), (16,117,245)]
def prob_viz(res, actions, input_frame, colors):
    output_frame = input_frame.copy()
    for num, prob in enumerate(res):
        cv2.rectangle(output_frame, (0,60+num*40), (int(prob*100), 90+num*40), colors[num], -1)
        cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
        
    return output_frame

# %%
plt.figure(figsize=(18,18))
plt.imshow(prob_viz(res, actions, image, colors))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13112/104962489.py in <module>
#       1 plt.figure(figsize=(18,18))
# ----> 2 plt.imshow(prob_viz(res, actions, image, colors))
#
# NameError: name 'image' is not defined

# %%
sequence.reverse()

# %%
len(sequence)

# %%
sequence.append('def')

# %%
sequence.reverse()

# %%
sequence[-30:]

# %%
# 1. New detection variables
sequence = []
sentence = []
threshold = 0.4

cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)
        
        # 2. Prediction logic
        keypoints = extract_keypoints(results)
#         sequence.insert(0,keypoints)
#         sequence = sequence[:30]
        sequence.append(keypoints)
        sequence = sequence[-30:]
        
        if len(sequence) == 30:
            res = model.predict(np.expand_dims(sequence, axis=0))[0]
            print(actions[np.argmax(res)])
            
            
        #3. Viz logic
            if res[np.argmax(res)] > threshold: 
                if len(sentence) > 0: 
                    if actions[np.argmax(res)] != sentence[-1]:
                        sentence.append(actions[np.argmax(res)])
                else:
                    sentence.append(actions[np.argmax(res)])

            if len(sentence) > 5: 
                sentence = sentence[-5:]

            # Viz probabilities
            image = prob_viz(res, actions, image, colors)
            
        cv2.rectangle(image, (0,0), (640, 40), (245, 117, 16), -1)
        cv2.putText(image, ' '.join(sentence), (3,30), 
                       cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
        
        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou

# %%
cap.release()
cv2.destroyAllWindows()

# %%
res[np.argmax(res)] > threshold
# Out:
# True

# %%
(num_sequences,30,1662)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13112/641301155.py in <module>
# ----> 1 (num_sequences,30,1662)
#
# NameError: name 'num_sequences' is not defined

# %%
model.predict(np.expand_dims(X_test[0], axis=0))
# Out:
# array([[1.1495755e-01, 6.2063587e-04, 8.8442177e-01]], dtype=float32)
